# %% [markdown]
# # 《python 数据可视化之 matplotlib 实践》
#
# ## 坐标轴高阶应用
#
# ![overview](overview.png)

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %%
matplotlib.__version__
# Out:
# '3.10.0'

# %%
# %matplotlib inline

# %% [markdown]
# ### 案例1: 向画布中的任意位置添加任意数量的坐标轴

# %%
fig = plt.figure()

# 坐标抽实例
# 矩形(左, 底, 宽, 高)
ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.5, 0.2, 1, 0.5])

ax1.set_title("Title1")
ax2.set_title("Title2")

plt.axes([0.05, 0.7, 0.3, 0.3], frameon=True, aspect="equal")
plt.plot(np.arange(3), [0, 1, 0], color="blue", linewidth=2, linestyle="--")

plt.axes([0.2, 0.2, 0.3, 0.3], frameon=True, aspect="equal")
plt.plot(np.arange(3), [0, 1, 0], color="r", linewidth=2, linestyle="-")

plt.axes([0.8, 0.7, 0.3, 0.3], frameon=True, aspect="equal")
plt.plot(np.arange(3), [0, 1, 0], color="blue", linewidth=2, linestyle=":")

plt.show()

# %%
fig = plt.figure()

# 坐标抽实例
# 矩形 (左, 底, 宽, 高)
plt.axes([0.1, 0.9, 0.3, 0.5])
plt.plot(np.arange(3), [0, 1, 0], color="blue", linewidth=2, linestyle="--")

plt.axes([0.2, 0.4, 0.3, 0.5], aspect="equal")
plt.plot(np.arange(3), [0, 1, 0], color="r", linewidth=2, linestyle="-")

plt.axes([0.3, -0.1, 0.3, 0.5], frameon=True)
plt.plot(np.arange(3), [0, 1, 0], color="blue", linewidth=2, linestyle=":")

plt.show()

# %% [markdown]
# ### 案例2: 调整已经确定的坐标轴的显示、隐藏与刻度范围等问题

# %%
fig = plt.figure()

# 坐标抽实例
# 矩形 (左, 底, 宽, 高)
plt.axes([0.1, 0.9, 0.3, 0.5])
plt.plot(np.arange(3), [0, 1, 0], color="blue", linewidth=2, linestyle="--")
plt.axis("image")

plt.axes([0.2, 0.4, 0.3, 0.5], aspect="equal")
plt.plot(np.arange(3), [0, 1, 0], color="r", linewidth=2, linestyle="-")

plt.axes([0.3, -0.1, 0.3, 0.5], frameon=True)
plt.plot(np.arange(3), [0, 1, 0], color="blue", linewidth=2, linestyle=":")
plt.axis("off")

plt.show()

# %% [markdown]
# ### 使用 axis() 函数绘制坐标轴

# %%
plt.axis([0.1, 0.9, 0.3, 0.5])
plt.plot(np.arange(3), [0, 1, 0], color="blue", linewidth=2, linestyle="--")
plt.show()

# %% [markdown]
# ### 两种方法控制坐标轴刻度的显示
#
# - Axes.set_xticks() or Axes.set_yticks()
# - plt.setp()

# %%
ax1 = plt.subplot(121)
ax1.set_xticks(range(0, 251, 50))  # 设置 x 轴坐标从 0 到 250, 每隔 50 刻度一次
plt.grid(axis="x")  # 注意, 网格线是根据 tick 刻度来画的, 有几个刻度画几条线

ax2 = plt.subplot(122)
ax2.set_xticks([])  # 设置 x 轴坐标为空
ax2.set_yticks(range(-10, 10, 5))  # 设置 y 轴坐标, 从 -10 到 10,  每隔 5 刻度一次
plt.grid(
    axis="x"
)  # 注意, 网格线是根据 tick 刻度来画的, 有几个刻度画几条线, 该子图没有 x 刻度, 则不会划线

plt.show()

# %%
ax1 = plt.subplot(221)
plt.setp(ax1.get_xticklabels(), visible=True)
plt.setp(ax1.get_xticklines(), visible=True)
plt.grid(axis="x")

ax2 = plt.subplot(222)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklines(), visible=False)
plt.grid(axis="x")

ax3 = plt.subplot(223)
plt.setp(ax3.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklines(), visible=True)  # 与下面那个子图相比, 少了x轴的刻度线
plt.grid(axis="x")

ax4 = plt.subplot(224)
plt.setp(ax4.get_xticklabels(), visible=True)
plt.setp(ax4.get_xticklines(), visible=False)  #
plt.grid(axis="x")

# %% [markdown]
# ### 控制坐标轴的显示

# %%
t = np.arange(0.05, 10.0, 0.01)
s1 = np.exp(t)
s2 = np.cos(t)

ax1 = plt.subplot(121)
ax1.plot(t, s1)
ax1.spines["right"].set_color("none")  # 不显示上面、右边的刻度线
ax1.spines["top"].set_color("none")
ax1.set_xlim(-1, 2)
ax1.set_ylim(0, 3)
plt.title("$\exp(x)$")

ax2 = plt.subplot(122)
ax2.plot(t, s2)
ax2.spines["right"].set_color("none")  # 不显示上面、右边的刻度线
ax2.spines["top"].set_color("none")
ax2.xaxis.set_ticks_position("top")  # 把刻度线移动到下面, 也可以不写(默认)
ax2.set_xlim(-1, 2)
ax2.set_ylim(0, 3)
plt.title("$\cos(x)$")

plt.show()

# %% [markdown]
# ### 移动坐标轴位置

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 200)
y_1 = np.sin(x)
y_2 = np.cos(x)

plt.subplot(211)
plt.xlim(-2 * np.pi, 2 * np.pi)
plt.xticks(
    [
        -2 * np.pi,
        -1.5 * np.pi,
        -np.pi,
        -0.5 * np.pi,
        0,
        0.5 * np.pi,
        np.pi,
        1.5 * np.pi,
        2 * np.pi,
    ],
    [
        r"$-2\pi$",
        r"$-3\pi/2$",
        r"$-\pi$",
        r"$\pi/2$",
        r"$0$",
        r"$\pi/2$",
        r"$\pi$",
        r"$3\pi/2$",
        r"$2\pi$",
    ],
)

plt.plot(x, y_1, label=r"$\sin(x)$")
plt.plot(x, y_2, label=r"$\cos(x)$")
plt.grid(axis="x", color="gray", ls=":")
plt.legend(loc="lower left", bbox_to_anchor=(1, 0.5, 0.9, 0.9))


ax = plt.subplot(212)
ax.spines["right"].set_color("none")
ax.spines["top"].set_color("none")
# 移动两个轴
ax.spines["left"].set_position(("data", 0))
ax.spines["bottom"].set_position(("data", 0))

ax.set_xlim(-2 * np.pi, 2 * np.pi)  # 这里通过ax设置,也可以通过plt设置
plt.xticks(
    [
        -2 * np.pi,
        -1.5 * np.pi,
        -np.pi,
        -0.5 * np.pi,
        0,
        0.5 * np.pi,
        np.pi,
        1.5 * np.pi,
        2 * np.pi,
    ],
    [
        r"$-2\pi$",
        r"$-3\pi/2$",
        r"$-\pi$",
        r"$\pi/2$",
        r"$0$",
        r"$\pi/2$",
        r"$\pi$",
        r"$3\pi/2$",
        r"$2\pi$",
    ],
)

plt.plot(x, y_1, label=r"$\sin(x)$")
plt.plot(x, y_2, label=r"$\cos(x)$")
plt.grid(axis="x", color="gray", ls=":")
plt.show()
